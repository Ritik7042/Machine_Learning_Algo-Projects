# %%
import pandas as pd

# %% [markdown]
# # Data Prediction

# %%
pd.read_csv("titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("titanic.csv",usecols=["Survived","Pclass","Sex","Age","Fare"])

# %%
df1 = pd.get_dummies(df["Sex"])

# %%
df2 = pd.concat([df,df1],axis=1)

# %%
df2
# Out:
#      Survived  Pclass     Sex   Age     Fare  female  male
# 0           0       3    male  22.0   7.2500       0     1
# 1           1       1  female  38.0  71.2833       1     0
# 2           1       3  female  26.0   7.9250       1     0
# 3           1       1  female  35.0  53.1000       1     0
# 4           0       3    male  35.0   8.0500       0     1
# ..        ...     ...     ...   ...      ...     ...   ...
# 886         0       2    male  27.0  13.0000       0     1
# 887         1       1  female  19.0  30.0000       1     0
# 888         0       3  female   NaN  23.4500       1     0
# 889         1       1    male  26.0  30.0000       0     1
# 890         0       3    male  32.0   7.7500       0     1
#
# [891 rows x 7 columns]

# %%
df2.drop("Sex",axis="columns",inplace=True)

# %%
df2
# Out:
#      Survived  Pclass   Age     Fare  female  male
# 0           0       3  22.0   7.2500       0     1
# 1           1       1  38.0  71.2833       1     0
# 2           1       3  26.0   7.9250       1     0
# 3           1       1  35.0  53.1000       1     0
# 4           0       3  35.0   8.0500       0     1
# ..        ...     ...   ...      ...     ...   ...
# 886         0       2  27.0  13.0000       0     1
# 887         1       1  19.0  30.0000       1     0
# 888         0       3   NaN  23.4500       1     0
# 889         1       1  26.0  30.0000       0     1
# 890         0       3  32.0   7.7500       0     1
#
# [891 rows x 6 columns]

# %%
df2["Age"].mean()
# Out:
# 29.69911764705882

# %%
df2["Fare"].mean()
# Out:
# 32.2042079685746

# %% [markdown]
# ##

# %%
df2["Age"] = df2["Age"].fillna(df2["Age"].mean())

# %%
df2
# Out:
#      Survived  Pclass        Age     Fare  female  male
# 0           0       3  22.000000   7.2500       0     1
# 1           1       1  38.000000  71.2833       1     0
# 2           1       3  26.000000   7.9250       1     0
# 3           1       1  35.000000  53.1000       1     0
# 4           0       3  35.000000   8.0500       0     1
# ..        ...     ...        ...      ...     ...   ...
# 886         0       2  27.000000  13.0000       0     1
# 887         1       1  19.000000  30.0000       1     0
# 888         0       3  29.699118  23.4500       1     0
# 889         1       1  26.000000  30.0000       0     1
# 890         0       3  32.000000   7.7500       0     1
#
# [891 rows x 6 columns]

# %% [markdown]
# df2

# %%
x=df2.drop("Survived",axis="columns")

# %%
y=df2["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict([[3,36,32,0,1]])
# Out:
# array([0.03952176])

# %%
model.score(x_test,y_test)
# Out:
# 0.36010402386026075

# %% [markdown]
# # Logistic Regression

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.8212290502793296

# %%
model.predict([[3,36,32,0,1]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
input = df2.drop('Survived',axis='columns')

# %%
target = df2['Survived']

# %%
model.fit(input, target)
# Out:
# DecisionTreeClassifier()

# %%
model.predict([[3,36,32,0,1]])
# Out:
# array([0], dtype=int64)

# %%
model.score(input, target)
# Out:
# 0.9797979797979798

# %% [markdown]
# # Randnom forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model2 = RandomForestClassifier()

# %%
model2.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.9776536312849162

# %%
model.predict([[3,36,32,0,1]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Kfolding

# %%
from sklearn.model_selection import cross_val_score

# %%
from sklearn.svm import SVC

# %%
df = cross_val_score(SVC(),x_test,y_test,cv=4)

# %%
df
# Out:
# array([0.71111111, 0.64444444, 0.62222222, 0.65909091])

# %%
import numpy as np

# %%
np.average(df)
# Out:
# 0.6592171717171718

# %%
df = cross_val_score(RandomForestClassifier(n_estimators=20),x_test,y_test,cv=4)

# %%
np.average(df)
# Out:
# 0.7983585858585859

# %%
df = cross_val_score(RandomForestClassifier(n_estimators=15),x_test,y_test,cv=10)

# %%
np.average(df)
# Out:
# 0.7764705882352941

# %%
df = cross_val_score(RandomForestClassifier(n_estimators=30),x_test,y_test,cv=10)

# %%
np.average(df)
# Out:
# 0.8045751633986928
