# %%
import pandas as pd

# %%
df = pd.read_csv("carprices (1).csv")

# %%
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
df1 = pd.get_dummies(df["Car Model"])

# %%
df1
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
df2 = pd.concat([df,df1],axis=1)

# %%
df2
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6        0       1
# 1                  BMW X5    35000          34000         3        0       1
# 2                  BMW X5    57000          26100         5        0       1
# 3                  BMW X5    22500          40000         2        0       1
# 4                  BMW X5    46000          31500         4        0       1
# 5                 Audi A5    59000          29400         5        1       0
# 6                 Audi A5    52000          32000         5        1       0
# 7                 Audi A5    72000          19300         6        1       0
# 8                 Audi A5    91000          12000         8        1       0
# 9   Mercedez Benz C class    67000          22000         6        0       0
# 10  Mercedez Benz C class    83000          20000         7        0       0
# ...

# %%
df2.drop("Car Model",axis="columns",inplace=True)

# %%
df2
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0     69000          18000         6        0       1                      0
# 1     35000          34000         3        0       1                      0
# 2     57000          26100         5        0       1                      0
# 3     22500          40000         2        0       1                      0
# 4     46000          31500         4        0       1                      0
# 5     59000          29400         5        1       0                      0
# 6     52000          32000         5        1       0                      0
# 7     72000          19300         6        1       0                      0
# 8     91000          12000         8        1       0                      0
# 9     67000          22000         6        0       0                      1
# 10    83000          20000         7        0       0                      1
# ...

# %%
x = df2.drop("Sell Price($)",axis="columns")

# %%
y = df2["Sell Price($)"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_train)
# Out:
# array([30097.64786481, 12687.90248915, 25034.67686686, 32210.68166248,
#        20714.71797214, 20646.9113953 , 32285.28202786, 41307.05640557,
#        35160.61886275, 27154.50445307])

# %%
x
# Out:
#     Mileage  Age(yrs)  Audi A5  BMW X5  Mercedez Benz C class
# 0     69000         6        0       1                      0
# 1     35000         3        0       1                      0
# 2     57000         5        0       1                      0
# 3     22500         2        0       1                      0
# 4     46000         4        0       1                      0
# 5     59000         5        1       0                      0
# 6     52000         5        1       0                      0
# 7     72000         6        1       0                      0
# 8     91000         8        1       0                      0
# 9     67000         6        0       0                      1
# 10    83000         7        0       0                      1
# 11    79000         7        0       0                      1
# 12    59000         5        0       0                      1

# %%
model.predict([[45000,4,0,0,1]])
# Out:
# array([39515.18611555])

# %%
model.predict([[86000,7,0,1,0]])
# Out:
# array([9852.55766157])

# %%
model.score(x_train,y_train)
# Out:
# 0.9770384435697266

# %% [markdown]
# # Second Method

# %%
df = pd.read_csv("carprices (1).csv")

# %%
df1 = pd.get_dummies(df["Car Model"])

# %%
df1
# Out:
#     Audi A5  BMW X5  Mercedez Benz C class
# 0         0       1                      0
# 1         0       1                      0
# 2         0       1                      0
# 3         0       1                      0
# 4         0       1                      0
# 5         1       0                      0
# 6         1       0                      0
# 7         1       0                      0
# 8         1       0                      0
# 9         0       0                      1
# 10        0       0                      1
# 11        0       0                      1
# 12        0       0                      1

# %%
df2 = pd.concat([df,df1],axis=1)

# %%
df2
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5  \
# 0                  BMW X5    69000          18000         6        0       1
# 1                  BMW X5    35000          34000         3        0       1
# 2                  BMW X5    57000          26100         5        0       1
# 3                  BMW X5    22500          40000         2        0       1
# 4                  BMW X5    46000          31500         4        0       1
# 5                 Audi A5    59000          29400         5        1       0
# 6                 Audi A5    52000          32000         5        1       0
# 7                 Audi A5    72000          19300         6        1       0
# 8                 Audi A5    91000          12000         8        1       0
# 9   Mercedez Benz C class    67000          22000         6        0       0
# 10  Mercedez Benz C class    83000          20000         7        0       0
# ...

# %%
df2.drop("Car Model",axis="columns",inplace=True)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
x = df2.drop("Sell Price($)",axis="columns")

# %%
y = df2["Sell Price($)"]

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[45000,4,0,0,1]])
# Out:
# array([36991.31721061])

# %%
model.predict([[86000,7,0,1,0]])
# Out:
# array([11080.74313219])

# %%
model.score(x,y)
# Out:
# 0.9417050937281082

# %% [markdown]
# # Verify

# %%
model.coef_
# Out:
# array([-3.70122094e-01, -1.33245363e+03,  6.10375284e+02, -3.67429130e+03,
#         3.06391602e+03])

# %%
model.intercept_
# Out:
# 55912.70994756205

# %% [markdown]
# # y = m1*1+m2*2+m3*3+c

# %%
y = 45000*-3.70122094e-01+4*-1.33245363e+03+0*6.10375284e+02+-3.67429130e+03*0+3.06391602e+03*1+55912.70994756205

# %%
y
# Out:
# 36991.31721756205
